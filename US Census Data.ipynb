# %%
import pandas as pd

# %%
csv_file = 'Resources/sub-est2021_1.csv'
census_2021_df = pd.read_csv(csv_file)
census_2021_df.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME  ESTIMATESBASE2020  POPESTIMATE2020  \
# 0          Alabama  Alabama            5024279          5024803
# 1   Abbeville city  Alabama               2368             2368
# 2  Adamsville city  Alabama               4372             4356
# 3     Addison town  Alabama                664              664
# 4       Akron town  Alabama                227              227
#
#    POPESTIMATE2021
# 0          5039877
# 1             2379
# 2             4294
# 3              668
# 4              226

# %%
csv_file_2 = 'Resources/SUB-IP-EST2019-ANNRES.csv'
census_2016_df = pd.read_csv(csv_file)
census_2016_df.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME  ESTIMATESBASE2020  POPESTIMATE2020  \
# 0          Alabama  Alabama            5024279          5024803
# 1   Abbeville city  Alabama               2368             2368
# 2  Adamsville city  Alabama               4372             4356
# 3     Addison town  Alabama                664              664
# 4       Akron town  Alabama                227              227
#
#    POPESTIMATE2021
# 0          5039877
# 1             2379
# 2             4294
# 3              668
# 4              226

# %%
us_cities_2021 = ['Atlanta',
            'Austin',
            'Baltimore',
            'Boston',
            'Buffalo',
            'Charlotte',
            'Chicago',
            'Cincinnati',
            'Cleveland',
            'Columbus',
            'Dallas',
            'Denver',
            'Detroit',
            'Green Bay',
            'Houston',
            'Indianapolis',
            'Jacksonville',
            'Kansas City',
            'Las Vegas',
            'Los Angeles',
            'Memphis',
            'Miami',
            'Minneapolis',
            'Milwaukee',
            'Nashville',
            'New Orleans',
            'New York',
            'Oakland',
            'Oklahoma City',
            'Orlando',
            'Philadelphia',
            'Phoenix',
            'Pittsburgh',
            'Portland',
            'Raleigh',
            'Sacramento',
            'Salt Lake',
            'San Antonio',
            'San Diego',
            'San Francisco',
            'San Jose',
            'St. Louis',
            'Seattle',
            'Tampa',
            'Washington',]
pro_us_cities_2021 = census_2021_df.loc[census_2021_df['NAME'].isin(us_cities_2021)]
pro_us_cities_2021
# Out:
# Empty DataFrame
# Columns: [SUMLEV, STATE, COUNTY, PLACE, COUSUB, CONCIT, PRIMGEO_FLAG, FUNCSTAT, NAME, STNAME, ESTIMATESBASE2020, POPESTIMATE2020, POPESTIMATE2021]
# Index: []
