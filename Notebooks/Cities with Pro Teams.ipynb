# %%
import pandas as pd
import requests

# %%
url = 'https://www.stadium-maps.com/facts/sports-franchises.html'

header = {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:101.0) Gecko/20100101 Firefox/101.0'}
r = requests.get(url, headers=header)
tables = pd.read_html(r.text.replace('<br>',','))
tables[0]
# Out:
#              City                   MLB (30 Teams)  \
# 0         Atlanta                   Atlanta Braves
# 1          Austin                              NaN
# 2       Baltimore                Baltimore Orioles
# 3          Boston                   Boston Red Sox
# 4         Buffalo                              NaN
# 5         Calgary                              NaN
# 6       Charlotte                              NaN
# 7         Chicago  Chicago Cubs  ,Chicago Whitesox
# 8      Cincinnati                  Cincinnati Reds
# 9       Cleveland                Cleveland Indians
# 10       Columbus                              NaN
# 11         Dallas                    Texas Rangers
# 12         Denver                 Colorado Rockies
# 13        Detroit                   Detroit Tigers
# 14       Edmonton                              NaN
# 15      Green Bay                              NaN
# 16        Houston                   Houston Astros
# 17   Indianapolis                              NaN
# 18   Jacksonville                              NaN
# 19    Kansas City               Kansas City Royals
# 20      Las Vegas                              NaN
# 21    Los Angeles             LA Dodgers,LA Angels
# 22        Memphis                              NaN
# 23          Miami                    Miami Marlins
# 24    Minneapolis                  Minnesota Twins
# 25      Milwaukee                Milwaukee Brewers
# 26       Montreal                              NaN
# 27      Nashville                              NaN
# 28    New Orleans                              NaN
# 29       New York   New York Yankees,New York Mets
# 30        Oakland                      Oakland A's
# 31  Oklahoma City                              NaN
# 32         Ottawa                              NaN
# 33        Orlando                              NaN
# 34   Philadelphia            Philadelphia Phillies
# 35        Phoenix            Arizona Diamond Backs
# 36     Pittsburgh               Pittsburgh Pirates
# 37       Portland                              NaN
# 38        Raleigh                              NaN
# 39     Sacramento                              NaN
# 40      Salt Lake                              NaN
# 41    San Antonio                              NaN
# 42      San Diego                 San Diego Padres
# 43  San Francisco             San Francisco Giants
# 44       San Jose                              NaN
# 45      St. Louis              St. Louis Cardinals
# 46        Seattle                 Seattle Mariners
# 47          Tampa                   Tampa Bay Rays
# 48        Toronto                Toronto Blue Jays
# 49      Vancouver                              NaN
# 50     Washington             Washington Nationals
# 51       Winnipeg                              NaN
#
#                    NFL (32 Teams)                 NBA (30 Teams)  \
# 0                 Atlanta Falcons                  Atlanta Hawks
# 1                             NaN                            NaN
# 2                Baltimore Ravens                            NaN
# 3            New England Patriots                 Boston Celtics
# 4                   Buffalo Bills                            NaN
# 5                             NaN                            NaN
# 6               Carolina Panthers              Charlotte Hornets
# 7                   Chicago Bears                  Chicago Bulls
# 8              Cincinnati Bengals                            NaN
# 9                Cleveland Browns            Cleveland Cavaliers
# 10                            NaN                            NaN
# 11                 Dallas Cowboys               Dallas Mavericks
# 12                 Denver Broncos                 Denver Nuggets
# 13                  Detroit Lions                Detroit Pistons
# 14                            NaN                            NaN
# 15              Green Bay Packers                            NaN
# 16                 Houston Texans                Houston Rockets
# 17             Indianapolis Colts                 Indiana Pacers
# 18           Jacksonville Jaguars                            NaN
# 19             Kansas City Chiefs                            NaN
# 20              Las Vegas Raiders                            NaN
# 21            LA Rams,LA Chargers          LA Lakers,LA Clippers
# 22                            NaN              Memphis Grizzlies
# 23                 Miami Dolphins                     Miami Heat
# 24              Minnesota Vikings         Minnesota Timberwolves
# 25                            NaN                Milwaukee Bucks
# 26                            NaN                            NaN
# 27               Tennessee Titans                            NaN
# 28             New Orleans Saints           New Orleans Pelicans
# 29  New York Giants,New York Jets  New York Knicks,Brooklyn Nets
# 30                            NaN                            NaN
# 31                            NaN          Oklahoma City Thunder
# 32                            NaN                            NaN
# 33                            NaN                  Orlando Magic
# 34            Philadelphia Eagles             Philadelphia 76ers
# 35              Arizona Cardinals                   Phoenix Suns
# 36            Pittsburgh Steelers                            NaN
# 37                            NaN          Portland Trailblazers
# 38                            NaN                            NaN
# 39                            NaN               Sacramento Kings
# 40                            NaN                      Utah Jazz
# 41                            NaN              San Antonio Spurs
# 42                            NaN                            NaN
# 43            San Francisco 49ers          Golden State Warriors
# 44                            NaN                            NaN
# 45                            NaN                            NaN
# 46               Seattle Seahawks                            NaN
# 47           Tampa Bay Buccaneers                            NaN
# 48                            NaN                Toronto Raptors
# 49                            NaN                            NaN
# 50            Washington Football             Washington Wizards
# 51                            NaN                            NaN
#
#                                        NHL (32 Teams)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                       Boston Bruins
# 4                                      Buffalo Sabres
# 5                                      Calgary Flames
# 6                                                 NaN
# 7                                  Chicago Blackhawks
# 8                                                 NaN
# 9                                                 NaN
# 10                              Columbus Blue Jackets
# 11                                       Dallas Stars
# 12                                 Colorado Avalanche
# 13                                  Detroit Red Wings
# 14                                    Edmonton Oilers
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                               Vegas Golden Knights
# 21                             LA Kings,Anaheim Ducks
# 22                                                NaN
# 23                                   Florida Panthers
# 24                                     Minnesota Wild
# 25                                                NaN
# 26                                 Montreal Canadiens
# 27                                Nashville Predators
# 28                                                NaN
# 29  New York Rangers,New York Islanders,New Jersey...
# 30                                                NaN
# 31                                                NaN
# 32                                    Ottawa Senators
# 33                                                NaN
# 34                                Philadelphia Flyers
# 35                                    Arizona Coyotes
# 36                                Pittsburgh Penguins
# 37                                                NaN
# 38                                Carolina Hurricanes
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                    San Jose Sharks
# 45                                    St. Louis Blues
# 46                                     Seattle Kraken
# 47                               Tampa Bay Lightening
# 48                                Toronto Maple Leafs
# 49                                  Vancouver Canucks
# 50                                Washington Capitals
# 51                                      Winnipeg Jets
#
#                          MLS (27 Teams)
# 0                        Atlanta United
# 1                             Austin FC
# 2                                   NaN
# 3                New England Revolution
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                          Chicago Fire
# 8                         FC Cincinnati
# 9                                   NaN
# 10                        Columbus Crew
# 11                            FC Dallas
# 12                      Colorado Rapids
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                       Houston Dynamo
# 17                                  NaN
# 18                                  NaN
# 19                 Sporting Kansas City
# 20                                  NaN
# 21                      LA Galaxy,LA FC
# 22                                  NaN
# 23                          Inter Miami
# 24                     Minnesota United
# 25                                  NaN
# 26                      Montreal Impact
# 27                         Nashville SC
# 28                                  NaN
# 29  New York Red Bulls,New York City FC
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                         Orlando City
# 34                   Philadelphia Union
# 35                                  NaN
# 36                                  NaN
# 37                     Portland Timbers
# 38                                  NaN
# 39                                  NaN
# 40                       Real Salt Lake
# 41                                  NaN
# 42                                  NaN
# 43                                  NaN
# 44                  San Jose Eathquakes
# 45                                  NaN
# 46                     Seattle Sounders
# 47                                  NaN
# 48                           Toronto FC
# 49                  Vancouver Whitecaps
# 50                            DC United
# 51                                  NaN
